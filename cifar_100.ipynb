# %%
import numpy as np
import tensorflow as tf
import keras
from keras import layers
import matplotlib.pyplot as plt

cifar_100=keras.datasets.cifar100
(X_train,Y_train),(X_test,Y_test)=cifar_100.load_data()

x_train=X_train/255
x_test=X_test/255

print(x_train.shape)
print(x_test.shape)
# Out:
# 2023-08-30 09:12:26.199835: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-30 09:12:26.397032: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-08-30 09:12:26.397745: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-08-30 09:12:26.445292: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import tensorflow as tf
from keras import layers
model=tf.keras.models.Sequential([layers.Conv2D(32,(3,3),activation='relu',input_shape=(32,32,3)),layers.MaxPool2D(),layers.Conv2D(32,(3,3),activation='relu'),layers.MaxPool2D(),layers.Conv2D(64,(5,5),activation='relu'),layers.Flatten(),layers.Dense(48,activation='relu'),layers.Dense(100,activation='softmax')])

#model.summary()
model.compile(optimizer=tf.keras.optimizers.SGD(),loss=tf.keras.losses.sparse_categorical_crossentropy,metrics=['accuracy'])

history=model.fit(x_train,Y_train,epochs=100,validation_data=(x_test,Y_test))


print(x_train.shape)
# Out:
# 2023-08-30 09:12:32.189140: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-08-30 09:12:32.189187: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-08-30 09:12:32.189208: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (p-7b7e996c-5e37-4380-88a4-b0cdb0d76861): /proc/driver/nvidia/version does not exist
# 2023-08-30 09:12:32.189458: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# ...

# %%
model.evaluate(X_test,Y_test)
# Out:
# 313/313 [==============================] - 4s 12ms/step - loss: 1223.1333 - accuracy: 0.1272
# [1223.13330078125, 0.12720000743865967]

# %%
print(history.history['accuracy'])
# Out:
# [0.014659999869763851, 0.029659999534487724, 0.06412000209093094, 0.095660001039505, 0.12921999394893646, 0.15780000388622284, 0.18050000071525574, 0.20124000310897827, 0.2176000028848648, 0.2348400056362152, 0.24969999492168427, 0.2646600008010864, 0.27667999267578125, 0.2872999906539917, 0.3007799983024597, 0.31205999851226807, 0.32207998633384705, 0.33024001121520996, 0.3404799997806549, 0.3481599986553192, 0.35694000124931335, 0.3635999858379364, 0.3709000051021576, 0.3773599863052368, 0.3840000033378601, 0.388480007648468, 0.3947399854660034, 0.40167999267578125, 0.4087800085544586, 0.41312000155448914, 0.41780000925064087, 0.4233799874782562, 0.4275200068950653, 0.4347800016403198, 0.4397999942302704, 0.4427799880504608, 0.445360004901886, 0.4532400071620941, 0.4551999866962433, 0.46323999762535095, 0.46661999821662903, 0.46963998675346375, 0.4737600088119507, 0.47738000750541687, 0.48302000761032104, 0.4869399964809418, 0.4906199872493744, 0.49239999055862427, 0.49759998917579
# ...

# %%
plt.plot(history.history['loss'], label='loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(loc='upper right')

plt.plot(history.history['accuracy'], label='accuracy')
#plt.plot(history.history['accuracy'], label = 'accuracy')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.title('cifar_100')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7b7e996c-5e37-4380-88a4-b0cdb0d76861' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
